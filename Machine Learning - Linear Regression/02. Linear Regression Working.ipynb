# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("USA_Housing.csv")

# %%
df
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# ...

# %% [markdown]
# Here all column names are not looking proper... so I am renaming them

# %%
df.columns = ['Income', 'House_Age', 'Rooms', 'Bedrooms', 'Area_Population', 'Price', 'Address']

# %%
df
# Out:
#             Income  House Age     Rooms  Bedrooms  Area Population  \
# 0     79545.458574   5.682861  7.009188      4.09     23086.800503
# 1     79248.642455   6.002900  6.730821      3.09     40173.072174
# 2     61287.067179   5.865890  8.512727      5.13     36882.159400
# 3     63345.240046   7.188236  5.586729      3.26     34310.242831
# 4     59982.197226   5.040555  7.839388      4.23     26354.109472
# ...            ...        ...       ...       ...              ...
# 4995  60567.944140   7.830362  6.137356      3.46     22837.361035
# 4996  78491.275435   6.999135  6.576763      4.02     25616.115489
# 4997  63390.686886   7.250591  4.805081      2.13     33266.145490
# 4998  68001.331235   5.534388  7.130144      5.44     42625.620156
# 4999  65510.581804   5.992305  6.792336      4.07     46501.283803
#
#              Price                                            Address
# 0     1.059034e+06  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# ...

# %% [markdown]
# ### How clean!

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Income           5000 non-null   float64
#  1   House Age        5000 non-null   float64
#  2   Rooms            5000 non-null   float64
#  3   Bedrooms         5000 non-null   float64
#  4   Area Population  5000 non-null   float64
#  5   Price            5000 non-null   float64
#  6   Address          5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
df.describe()
# Out:
#               Income    House Age        Rooms     Bedrooms  Area Population  \
# count    5000.000000  5000.000000  5000.000000  5000.000000      5000.000000
# mean    68583.108984     5.977222     6.987792     3.981330     36163.516039
# std     10657.991214     0.991456     1.005833     1.234137      9925.650114
# min     17796.631190     2.644304     3.236194     2.000000       172.610686
# 25%     61480.562388     5.322283     6.299250     3.140000     29403.928702
# 50%     68804.286404     5.970429     7.002902     4.050000     36199.406689
# 75%     75783.338666     6.650808     7.665871     4.490000     42861.290769
# max    107701.748378     9.519088    10.759588     6.500000     69621.713378
#
#               Price
# count  5.000000e+03
# mean   1.232073e+06
# std    3.531176e+05
# min    1.593866e+04
# 25%    9.975771e+05
# 50%    1.232669e+06
# 75%    1.471210e+06
# max    2.469066e+06

# %% [markdown]
# ###

# %% [markdown]
# ###  Plots

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.corr(), cmap= plt.cm.get_cmap('Blues', 7))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ###

# %% [markdown]
# ## Sklearn Training

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %% [markdown]
# ###

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop(['Price', 'Address'], axis= 1)
Y = df['Price']

# %%
Xtrain, Xtest, Ytrain, Ytest = train_test_split(X, Y, test_size= 0.4)

# %%
Xtrain.shape, Xtest.shape
# Out:
# ((3000, 5), (2000, 5))

# %% [markdown]
# ###

# %%
lm.fit(Xtrain, Ytrain)
# Out:
# LinearRegression()

# %%
lm.intercept_
# Out:
# -2647290.7748675095

# %%
lm.coef_
# Out:
# array([2.17270341e+01, 1.66131185e+05, 1.19703129e+05, 2.82176871e+03,
#        1.51395431e+01])

# %% [markdown]
# #### Good thing has just learnt!
# Whenever get the data, make it a DF to see more clearly

# %%
X
# Out:
#             Income  House_Age     Rooms  Bedrooms  Area_Population
# 0     79545.458574   5.682861  7.009188      4.09     23086.800503
# 1     79248.642455   6.002900  6.730821      3.09     40173.072174
# 2     61287.067179   5.865890  8.512727      5.13     36882.159400
# 3     63345.240046   7.188236  5.586729      3.26     34310.242831
# 4     59982.197226   5.040555  7.839388      4.23     26354.109472
# ...            ...        ...       ...       ...              ...
# 4995  60567.944140   7.830362  6.137356      3.46     22837.361035
# 4996  78491.275435   6.999135  6.576763      4.02     25616.115489
# 4997  63390.686886   7.250591  4.805081      2.13     33266.145490
# 4998  68001.331235   5.534388  7.130144      5.44     42625.620156
# 4999  65510.581804   5.992305  6.792336      4.07     46501.283803
#
# [5000 rows x 5 columns]

# %%
pd.DataFrame(lm.coef_, X.columns, columns= ['Coefficients'])
# Out:
#                   Coefficients
# Income               21.727034
# House_Age        166131.185205
# Rooms            119703.128645
# Bedrooms           2821.768707
# Area_Population      15.139543

# %% [markdown]
# #### Interpretation:
#
# This shows that, if every other features are fixed, and you tweak the value of a single feature, based on the slope the price will change!
#
# As it is linear regression, there can only be TWO points. here -
# `Income & Price`
#                                                                  `House age & Price`
#                                                                  `...`
#
# And why intercept is single value?
# # # Ask Grras for that!

# %% [markdown]
# ###

# %% [markdown]
# ###

# %% [markdown]
#     Till here we have just trained the model based on the features we had.
#     (Oh man! Have we just trained based on multiple features? I mean 6D
#         training? ... if yes ... then, that is called Bullshit!)

# %% [markdown]
# ## Prediction

# %%
prediction = lm.predict(Xtest)

# %%
prediction
# Out:
# array([1458633.67736725,  955974.3776403 , 1862799.21704981, ...,
#        1665257.58689496,  879282.95844231, 1143197.57830981])

# %% [markdown]
# ## Now let's see how are they differ from the original one.
#
# ### <font color='#db02b0'>1. Made Trick
# ### <font color='#00de85'>2. Usual Trick

# %% [markdown]
# ###

# %% [markdown]
# # <font color='#db02b0'>1. Made Trick </font>
# by ∞ me

# %%
testData = Xtest.copy().drop([*Xtest.columns], axis=1)

# %%
testData['Real'] = Ytest

# %%
testData.reset_index(inplace= True)

# %%
testData['Predict'] = prediction

# %%
testData
# Out:
#       index          Real       Predict
# 0      2329  1.534295e+06  1.458634e+06
# 1      3539  7.426451e+05  9.559744e+05
# 2      3525  1.882119e+06  1.862799e+06
# 3      4890  1.405496e+06  1.354578e+06
# 4      3858  1.491145e+06  1.589941e+06
# ...     ...           ...           ...
# 1995   4477  1.068856e+06  1.137626e+06
# 1996    303  1.414495e+06  1.494528e+06
# 1997      6  1.502056e+06  1.665258e+06
# 1998   2438  8.962461e+05  8.792830e+05
# 1999   1556  1.427843e+06  1.143198e+06
#
# [2000 rows x 3 columns]

# %%
fig = plt.figure(figsize= (20,10))
sns.scatterplot(x= 'index', y= 'Real', data= testData)
sns.scatterplot(x= 'index', y= 'Predict', data= testData)
# Out:
# <AxesSubplot:xlabel='index', ylabel='Real'>

# %% [markdown]
# # <font color='#db02b0'>1. Made Trick </font>
# from the course

# %%
plt.scatter(Ytest, prediction, marker='.')

# %% [markdown]
# #### Says that,
# It is a straight line which suggests that both are kind of correlated.
# And that is a nice thing.

# %% [markdown]
# # <font color='#f5005a'> BOOLi! SHOOLi! HOOLi!
#
# Amazing trick just learnt!
#
# We all know that the so called `residuals` are `Y - Ycap` and to plot the histogram of those residuals, we can do something like this.

# %% [markdown]
# ## <font color='#00de85'>2. Usual Trick

# %%
sns.histplot((Ytest - prediction))
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Count'>

# %% [markdown]
# #

# %% [markdown]
# > ## <font face='eb garamond'> <i> <center> **Predictive modeling is the problem of developing a model <br> using historical data to make a prediction on new data <br> where we do not have the answer.** </center> </i> </font>
#
#     That's why we want to find whether our model is good or not...
#     See things below!
#
# <br> <br> <br>
# <font face='eb garamond' size= 100> " How do I get the <u> accuracy of my regression model </u> "</font>
# <br> <br> <br>
# Accuracy (e.g. classification accuracy) is a measure for classification, not regression.

# %% [markdown]
# ## Regression Evaluation Metrics
#
# <font color= "#34cceb"> **Evaluation metrics for a linear regression model. Evaluation metrics are a measure of how <u>good</u> a model performs and how well it approximates the relationship.** </font>
#
#
# **Mean Absolute Error** (MAE) is the mean of the absolute value of the errors:
#
# $$\frac 1n\sum_{i=1}^n|y_i-\hat{y}_i|$$
#
# **Mean Squared Error** (MSE) is the mean of the squared errors:
#
# $$\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2$$
#
# **Root Mean Squared Error** (RMSE) is the square root of the mean of the squared errors:
#
# $$\sqrt{\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2}$$
#
# Comparing these metrics:
#
# - **MAE** is the easiest to understand, because it's the average error.
# - **MSE** is more popular than MAE, because MSE "punishes" larger errors, which tends to be useful in the real world.
# - **RMSE** is even more popular than MSE, because RMSE is interpretable in the "y" units.
#
# All of these are **loss functions**, because we want to minimize them.

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %% [markdown]
# Now that is the simple workflow!
#
# # That's it!
# In the upcoming selction, I will try ... my hands on the boston dataset.
